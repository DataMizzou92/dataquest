# %% [markdown]
# ## The aim of this project is to clean the auto.csv data and analyze the car listings within it. This will be done using Python's pandas

# %%
import pandas as pd
import numpy as np
autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
autos.head()
# Out:
#           date_crawled                            name  seller offer_type  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat    Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat    Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat    Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat    Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat    Angebot
#
#    price abtest vehicle_type  registration_year    gearbox  power_ps  model  \
# 0    480   test          NaN               1993    manuell         0   golf
# 1  18300   test        coupe               2011    manuell       190    NaN
# 2   9800   test          suv               2004  automatik       163  grand
# 3   1500   test   kleinwagen               2001    manuell        75   golf
# 4   3600   test   kleinwagen               2008    manuell        69  fabia
#
# ...

# %% [markdown]
# ### This dataset has alot of typos and various languages based upon where the vehicle is produced. This data will need to be cleaned.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
# Update the names of unwanted column names
autos.rename(columns = {'yearOfRegistration': 'registration_year',
                      'monthOfRegistration': 'registration_month',
                      'notRepairedDamage': 'unrepaired_damage',
                      'dateCreated': 'ad_created'}, inplace = True)

# Update camelcase to snakecase
autos.rename(columns = {'dateCrawled': 'date_crawled',
                        'offerType': 'offer_type',
                        'vehicleType': 'vehicle_type',
                        'powerPS': 'power_ps',
                        'fuelType': 'fuel_type',
                        'nrOfPictures': 'nr_of_pictures',
                        'postalCode': 'postal_code',
                        'lastSeen': 'last_seen'}, inplace = True)

# %%
autos.head()
# Out:
#           date_crawled                            name  seller offer_type  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat    Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat    Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat    Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat    Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat    Angebot
#
#    price abtest vehicle_type  registration_year    gearbox  power_ps  model  \
# 0    480   test          NaN               1993    manuell         0   golf
# 1  18300   test        coupe               2011    manuell       190    NaN
# 2   9800   test          suv               2004  automatik       163  grand
# 3   1500   test   kleinwagen               2001    manuell        75   golf
# 4   3600   test   kleinwagen               2008    manuell        69  fabia
#
# ...

# %% [markdown]
# ### This dataframe has had its columns renamed to be snakecase and renamed unwated names

# %%
autos.describe()
# Out:
#               price  registration_year       power_ps      kilometer  \
# count  3.715280e+05      371528.000000  371528.000000  371528.000000
# mean   1.729514e+04        2004.577997     115.549477  125618.688228
# std    3.587954e+06          92.866598     192.139578   40112.337051
# min    0.000000e+00        1000.000000       0.000000    5000.000000
# 25%    1.150000e+03        1999.000000      70.000000  125000.000000
# 50%    2.950000e+03        2003.000000     105.000000  150000.000000
# 75%    7.200000e+03        2008.000000     150.000000  150000.000000
# max    2.147484e+09        9999.000000   20000.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count       371528.000000        371528.0  371528.00000
# mean             5.734445             0.0   50820.66764
# std              3.712412             0.0   25799.08247
# min              0.000000             0.0    1067.00000
# 25%              3.000000             0.0   30459.00000
# ...

# %% [markdown]
# ### some columns like nr_of_pictures could be dropped from the df the kiloeter column needs to be investigated more

# %%
autos["price"].unique().shape
autos["price"].describe()
autos["price"].value_counts()
# Out:
# 0         10778
# 500        5670
# 1500       5394
# 1000       4649
# 1200       4594
#           ...
# 23456         1
# 171000        1
# 21830         1
# 13485         1
# 8188          1
# Name: price, Length: 5597, dtype: int64

# %%
autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
autos['ad_created'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
autos['last_seen'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.001292
# 2016-03-06    0.004134
# 2016-03-07    0.005262
# 2016-03-08    0.008056
# 2016-03-09    0.009994
# 2016-03-10    0.011563
# 2016-03-11    0.013046
# 2016-03-12    0.023401
# 2016-03-13    0.008489
# 2016-03-14    0.012301
# 2016-03-15    0.016411
# 2016-03-16    0.016419
# 2016-03-17    0.028760
# 2016-03-18    0.006931
# 2016-03-19    0.016314
# 2016-03-20    0.019915
# 2016-03-21    0.020136
# 2016-03-22    0.020607
# 2016-03-23    0.018149
# 2016-03-24    0.019237
# 2016-03-25    0.019097
# 2016-03-26    0.016160
# 2016-03-27    0.016909
# 2016-03-28    0.022273
# 2016-03-29    0.023312
# 2016-03-30    0.023856
# 2016-03-31    0.024238
# 2016-04-01    0.024022
# 2016-04-02    0.025016
# 2016-04-03    0.025366
# 2016-04-04    0.025654
# 2016-04-05    0.126206
# 2016-04-06    0.217830
# 2016-04-07    0.129648
# Name: last_seen, dtype: float64

# %%
autos['registration_year'].describe()
# Out:
# count    371528.000000
# mean       2004.577997
# std          92.866598
# min        1000.000000
# 25%        1999.000000
# 50%        2003.000000
# 75%        2008.000000
# max        9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# ### We should remove any dates that are below 1900 or higher than 2016 to get rid of bad date values

# %%
autos = autos[autos["registration_year"].between(1900, 2016)]

# %%
autos['registration_year'].value_counts(normalize=True)
# Out:
# 2000    0.068813
# 1999    0.063812
# 2005    0.062548
# 2006    0.056702
# 2001    0.056668
#           ...
# 1925    0.000003
# 1920    0.000003
# 1919    0.000003
# 1915    0.000003
# 1911    0.000003
# Name: registration_year, Length: 97, dtype: float64

# %% [markdown]
# ### The newest vehicle was in 2000 and the oldest was to 1911 so it appears that this dataset has an appropriate range for its dates

# %%
autos['brand'].value_counts(normalize=True)
autos.head()
# Out:
#           date_crawled                            name  seller offer_type  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat    Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat    Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat    Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat    Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat    Angebot
#
#    price abtest vehicle_type  registration_year    gearbox  power_ps  model  \
# 0    480   test          NaN               1993    manuell         0   golf
# 1  18300   test        coupe               2011    manuell       190    NaN
# 2   9800   test          suv               2004  automatik       163  grand
# 3   1500   test   kleinwagen               2001    manuell        75   golf
# 4   3600   test   kleinwagen               2008    manuell        69  fabia
#
# ...

# %% [markdown]
# ### I  will figure out the most expensive vehicles based upon mean price

# %%
auto = autos['brand'].value_counts().sort_values().head(20).index
makers = {}

for row in auto:
    brand = autos[autos['brand'] == row]
    price = brand['price'].mean()
    makers[row] = price

print(makers)
# Out:
# {'lada': 3030.3899082568805, 'lancia': 3218.629067245119, 'rover': 1524.3952483801295, 'daewoo': 1011.812865497076, 'saab': 3879.23166023166, 'trabant': 20828.153979238756, 'jaguar': 14232.819218241042, 'subaru': 4247.2744063324535, 'land_rover': 16823.68372703412, 'daihatsu': 1704.548717948718, 'jeep': 12207.964102564103, 'dacia': 5861.871853546911, 'chrysler': 3925.278093883357, 'chevrolet': 7485.864169927334, 'porsche': 51301.34594348222, 'suzuki': 4401.918811002662, 'alfa_romeo': 36896.85430463576, 'kia': 5719.187041564792, 'honda': 3863.605097894348, 'mitsubishi': 3298.8646998982704}

# %%
vehicles = pd.Series(makers)
print(vehicles)
# Out:
# lada           3030.389908
# lancia         3218.629067
# rover          1524.395248
# daewoo         1011.812865
# saab           3879.231660
# trabant       20828.153979
# jaguar        14232.819218
# subaru         4247.274406
# land_rover    16823.683727
# daihatsu       1704.548718
# jeep          12207.964103
# dacia          5861.871854
# chrysler       3925.278094
# chevrolet      7485.864170
# porsche       51301.345943
# suzuki         4401.918811
# alfa_romeo    36896.854305
# kia            5719.187042
# honda          3863.605098
# mitsubishi     3298.864700
# dtype: float64

# %%
df = pd.DataFrame(vehicles, columns=['mean_price'])
pricey = df.sort_values(['mean_price'], ascending=False)
new_df =  pricey[:3]
new_df
# Out:
#               mean_price
# porsche     51301.345943
# alfa_romeo  36896.854305
# trabant     20828.153979
